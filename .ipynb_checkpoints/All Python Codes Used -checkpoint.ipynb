# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import re
from jupyterthemes import jtplot
jtplot.style(theme='onedork')

# %% [markdown]
# ## Converting Fasta to TXT

# %%
def fasta_to_txt(inFile,outFile):
    try:
        with open(inFile,"r") as newFile:
            sequences = newFile.read()
            sequences = re.split("^>", sequences, flags=re.MULTILINE)  
            del sequences[0] 
            newFile.close()
    except IOError:
        print("Failed to open " + inFile)
    try:
        with open(outFile,"w") as newFasta:
            for fasta in sequences:
                try:
                    header, sequence = fasta.split("\n", 1) 
                except ValueError:
                    print(fasta)
                header = ">" + header + "\n" 
                sequence = sequence.replace("\n","") + "\n"
                print(sequence)
                newFasta.write(header + sequence)
            newFasta.close()
    except IOError:
        print("Failed to open " + inFile)
inFile  = "Seq1.fasta"
outFile = inFile + ".txt" 
fasta_to_txt(inFile,outFile)
print("Opening FASTA file...")
# Out:
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# ...
# Output Truncated ... Max Length Reached

# %% [markdown]
# ## Smith Waterman algorithm

# %%
from enum import IntEnum
import numpy as np

class Score(IntEnum):
    MATCH = 1
    MISMATCH = -1
    GAP = -1
class Trace(IntEnum):
    STOP = 0
    LEFT = 1
    UP = 2
    DIAGONAL = 3

def smith_waterman(seq1, seq2):
    row = len(seq1) + 1
    col = len(seq2) + 1
    matrix = np.zeros(shape=(row, col), dtype=np.int)
    tracing_matrix = np.zeros(shape=(row, col), dtype=np.int)
    max_score = -1
    max_index = (-1, -1)

    for i in range(1, row):
        for j in range(1, col):

            match_value = Score.MATCH if seq1[i - 1] == seq2[j - 1] else Score.MISMATCH
            diagonal_score = matrix[i - 1, j - 1] + match_value

            vertical_score = matrix[i - 1, j] + Score.GAP

            horizontal_score = matrix[i, j - 1] + Score.GAP

            matrix[i, j] = max(0, diagonal_score, vertical_score, horizontal_score)
            if matrix[i, j] == 0:
                tracing_matrix[i, j] = Trace.STOP

            elif matrix[i, j] == horizontal_score:
                tracing_matrix[i, j] = Trace.LEFT
            elif matrix[i, j] == vertical_score:
                tracing_matrix[i, j] = Trace.UP

            elif matrix[i, j] == diagonal_score:
                tracing_matrix[i, j] = Trace.DIAGONAL

            # Tracking the cell with the maximum score
            if matrix[i, j] >= max_score:
                max_index = (i,j)
                max_score = matrix[i, j]

    aligned_seq1 = ""
    aligned_seq2 = ""
    current_aligned_seq1 = ""
    current_aligned_seq2 = ""
    (max_i, max_j) = max_index
    while tracing_matrix[max_i, max_j] != Trace.STOP:
        if tracing_matrix[max_i, max_j] == Trace.DIAGONAL:
            current_aligned_seq1 = seq1[max_i - 1]
            current_aligned_seq2 = seq2[max_j - 1]
            max_i = max_i - 1
            max_j = max_j - 1
        elif tracing_matrix[max_i, max_j] == Trace.UP:
            current_aligned_seq1 = seq1[max_i - 1]
            current_aligned_seq2 = '-'
            max_i = max_i - 1
        elif tracing_matrix[max_i, max_j] == Trace.LEFT:
            current_aligned_seq1 = '-'
            current_aligned_seq2 = seq2[max_j - 1]
            max_j = max_j - 1
        aligned_seq1 = aligned_seq1 + current_aligned_seq1
        aligned_seq2 = aligned_seq2 + current_aligned_seq2
    aligned_seq1 = aligned_seq1[::-1]
    aligned_seq2 = aligned_seq2[::-1]
    return aligned_seq1, aligned_seq2


file1 = open("seq1file1_small")
file2 = open("seq2file1_small")
file_2_name, file_2  = fasta_reader("seq1file1_small")
out1,out2 = smith_waterman(file1, file2)
print(out1)
print(out2)
file1.close()
file2.close()

# %% [markdown]
# ## Sequence 1 Differences:

# %%
def read_only_lines(filepath, start, finish):
    f = open(filepath)
    for ii,line in enumerate(f):
        if ii>=start and ii<finish:
            yield line
        elif ii>=finish:
            return

def check_similairty(str1,str2):
    miss=0
    for i in range(len(str1)):
        if str1!=str2:
            miss+=1
    return round(( 1 - miss/len(str1))*100,4), len(str1), miss

file_path1 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq1rapid_lin.txt'
file_path2 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq1rapid.txt'
k = enumerate(f)

net = 0
tt = 0
m = 0
for i in range(k):
    str1 = read_only_lines(file_path1,k,k+10)
    str2 = read_only_lines(file_path2,k,k+10)
    acc,tt,m = check_similarity(str1,str2)
    print("Iteration ",i, "Accuracy ",u)
    net+=u
net = net/k
print("\n \n \n")
print("Total Base Pairs",tt)
print("Total Miss", m)
print("Net Accuracy",net)
# Out:
# Iteration 0 Accuracy 0.9961
# Iteration 1 Accuracy 0.9951
# Iteration 2 Accuracy 0.9866
# Iteration 3 Accuracy 0.9933
# Iteration 4 Accuracy 0.9906
# Iteration 5 Accuracy 0.9881
# Iteration 6 Accuracy 0.9968
# Iteration 7 Accuracy 0.9868
# Iteration 8 Accuracy 0.9999
# Iteration 9 Accuracy 0.9901
# Iteration 10 Accuracy 0.9946
# Iteration 11 Accuracy 0.9874
# Iteration 12 Accuracy 0.9928
# Iteration 13 Accuracy 0.9951
# Iteration 14 Accuracy 0.9949
# Iteration 15 Accuracy 0.9972
# Iteration 16 Accuracy 0.9941
# Iteration 17 Accuracy 0.9993
# Iteration 18 Accuracy 0.9877
# Iteration 19 Accuracy 0.9899
# Iteration 20 Accuracy 0.9956
# Iteration 21 Accuracy 0.9852
# Iteration 22 Accuracy 0.9939
# Iteration 23 Accuracy 0.985
# Iteration 24 Accuracy 0.9881
# Iteration 25 Accuracy 0.9905
# Iteration 26 Accuracy 0.9935
# Iteration 27 Accuracy 0.9853
# Iteration 28 Accuracy 0.9891
# Iteration 29 Accuracy 0.9865
# Iteration 30 Accuracy 0.9907
# Iteration 31 Accuracy 0.9976
# ...

# %%
def read_only_lines(filepath, start, finish):
    f = open(filepath)
    for ii,line in enumerate(f):
        if ii>=start and ii<finish:
            yield line
        elif ii>=finish:
            return

def check_similairty(str1,str2):
    miss=0
    for i in range(len(str1)):
        if str1!=str2:
            miss+=1
    return round(( 1 - miss/len(str1))*100,4), len(str1), miss

file_path1 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq1rapid_aff.txt'
file_path2 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq1rapid.txt'
k = len(enumerate(f))
net = 0
tt = 0
m = 0
for i in range(k):
    str1 = read_only_lines(file_path1,k,k+10)
    str2 = read_only_lines(file_path2,k,k+10)
    acc,tt,m = check_similarity(str1,str2)
    print("Iteration ",i, "Accuracy ",u)
    net+=u
net = net/k
print("\n \n \n")
print("Total Base Pairs",tt)
print("Total Miss", m)
print("Net Accuracy",net)
# Out:
# Iteration 0 Accuracy 0.9857
# Iteration 1 Accuracy 0.942
# Iteration 2 Accuracy 0.9869
# Iteration 3 Accuracy 0.9486
# Iteration 4 Accuracy 0.9744
# Iteration 5 Accuracy 0.9389
# Iteration 6 Accuracy 0.9839
# Iteration 7 Accuracy 0.9625
# Iteration 8 Accuracy 0.9815
# Iteration 9 Accuracy 0.954
# Iteration 10 Accuracy 0.9895
# Iteration 11 Accuracy 0.9674
# Iteration 12 Accuracy 0.962
# Iteration 13 Accuracy 0.9479
# Iteration 14 Accuracy 0.9357
# Iteration 15 Accuracy 0.9567
# Iteration 16 Accuracy 0.9686
# Iteration 17 Accuracy 0.9468
# Iteration 18 Accuracy 0.9454
# Iteration 19 Accuracy 0.9655
# Iteration 20 Accuracy 0.9723
# Iteration 21 Accuracy 0.9467
# Iteration 22 Accuracy 0.946
# Iteration 23 Accuracy 0.9407
# Iteration 24 Accuracy 0.9759
# Iteration 25 Accuracy 0.9848
# Iteration 26 Accuracy 0.9636
# Iteration 27 Accuracy 0.9884
# Iteration 28 Accuracy 0.9722
# Iteration 29 Accuracy 0.943
# Iteration 30 Accuracy 0.9793
# Iteration 31 Accuracy 0.9415
# ...

# %% [markdown]
# ## Sequence 2 Differences:

# %%
def read_only_lines(filepath, start, finish):
    f = open(filepath)
    for ii,line in enumerate(f):
        if ii>=start and ii<finish:
            yield line
        elif ii>=finish:
            return

def check_similairty(str1,str2):
    miss=0
    for i in range(len(str1)):
        if str1!=str2:
            miss+=1
    return round(( 1 - miss/len(str1))*100,4), len(str1), miss

file_path1 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq2rapid_lin.txt'
file_path2 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq2rapid.txt'
k = len(enumerate(f))
net = 0
tt = 0
m = 0
for i in range(k):
    str1 = read_only_lines(file_path1,k,k+10)
    str2 = read_only_lines(file_path2,k,k+10)
    acc,tt,m = check_similarity(str1,str2)
    print("Iteration ",i, "Accuracy ",u)
    net+=u
net = net/k
print("\n \n \n")
print("Total Base Pairs",tt)
print("Total Miss", m)
print("Net Accuracy",net)
# Out:
# Iteration 0 Accuracy 0.9876
# Iteration 1 Accuracy 0.9784
# Iteration 2 Accuracy 0.9914
# Iteration 3 Accuracy 0.9932
# Iteration 4 Accuracy 0.9825
# Iteration 5 Accuracy 0.9849
# Iteration 6 Accuracy 0.9799
# Iteration 7 Accuracy 0.9867
# Iteration 8 Accuracy 0.9757
# Iteration 9 Accuracy 0.976
# Iteration 10 Accuracy 0.9898
# Iteration 11 Accuracy 0.9772
# Iteration 12 Accuracy 0.9756
# Iteration 13 Accuracy 0.982
# Iteration 14 Accuracy 0.9877
# Iteration 15 Accuracy 0.99
# Iteration 16 Accuracy 0.9823
# Iteration 17 Accuracy 0.9817
# Iteration 18 Accuracy 0.9822
# Iteration 19 Accuracy 0.9928
# Iteration 20 Accuracy 0.9851
# Iteration 21 Accuracy 0.9904
# Iteration 22 Accuracy 0.9946
# Iteration 23 Accuracy 0.9846
# Iteration 24 Accuracy 0.9828
# Iteration 25 Accuracy 0.9944
# Iteration 26 Accuracy 0.9939
# Iteration 27 Accuracy 0.9765
# Iteration 28 Accuracy 0.9796
# Iteration 29 Accuracy 0.9814
# Iteration 30 Accuracy 0.9853
# Iteration 31 Accuracy 0.9987
# ...

# %%
def read_only_lines(filepath, start, finish):
    f = open(filepath)
    for ii,line in enumerate(f):
        if ii>=start and ii<finish:
            yield line
        elif ii>=finish:
            return

def check_similairty(str1,str2):
    miss=0
    for i in range(len(str1)):
        if str1!=str2:
            miss+=1
    return round(( 1 - miss/len(str1))*100,4), len(str1), miss

file_path1 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq2rapid_aff.txt'
file_path2 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq2rapid.txt'
k = len(enumerate(f))
net = 0
tt = 0
m = 0
for i in range(k):
    str1 = read_only_lines(file_path1,k,k+10)
    str2 = read_only_lines(file_path2,k,k+10)
    acc,tt,m = check_similarity(str1,str2)
    print("Iteration ",i, "Accuracy ",u)
    net+=u
net = net/k
print("\n \n \n")
print("Total Base Pairs",tt)
print("Total Miss", m)
print("Net Accuracy",net)
# Out:
# Iteration 0 Accuracy 0.9598
# Iteration 1 Accuracy 0.9472
# Iteration 2 Accuracy 0.9278
# Iteration 3 Accuracy 0.9557
# Iteration 4 Accuracy 0.9573
# Iteration 5 Accuracy 0.9433
# Iteration 6 Accuracy 0.9422
# Iteration 7 Accuracy 0.9415
# Iteration 8 Accuracy 0.959
# Iteration 9 Accuracy 0.9487
# Iteration 10 Accuracy 0.9347
# Iteration 11 Accuracy 0.9261
# Iteration 12 Accuracy 0.9283
# Iteration 13 Accuracy 0.9417
# Iteration 14 Accuracy 0.9577
# Iteration 15 Accuracy 0.9265
# Iteration 16 Accuracy 0.9492
# Iteration 17 Accuracy 0.9304
# Iteration 18 Accuracy 0.9334
# Iteration 19 Accuracy 0.9264
# Iteration 20 Accuracy 0.947
# Iteration 21 Accuracy 0.936
# Iteration 22 Accuracy 0.9388
# Iteration 23 Accuracy 0.9337
# Iteration 24 Accuracy 0.9268
# Iteration 25 Accuracy 0.9463
# Iteration 26 Accuracy 0.9487
# Iteration 27 Accuracy 0.9482
# Iteration 28 Accuracy 0.9466
# Iteration 29 Accuracy 0.9355
# Iteration 30 Accuracy 0.9409
# Iteration 31 Accuracy 0.9463
# ...

# %% [markdown]
# ## Smith Waterman Comparision

# %% [markdown]
# ### Rapid

# %%
def read_only_lines(filepath, start, finish):
    f = open(filepath)
    for ii,line in enumerate(f):
        if ii>=start and ii<finish:
            yield line
        elif ii>=finish:
            return

def check_similairty(str1,str2):
    miss=0
    for i in range(len(str1)):
        if str1!=str2:
            miss+=1
    return round(( 1 - miss/len(str1))*100,4), len(str1), miss

file_path1 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq1rapid.txt'
file_path2 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq1sw.txt'
k = len(enumerate(f))
net = 0
tt = 0
m = 0
for i in range(k):
    str1 = read_only_lines(file_path1,k,k+10)
    str2 = read_only_lines(file_path2,k,k+10)
    acc,tt,m = check_similarity(str1,str2)
    print("Iteration ",i, "Accuracy ",u)
    net+=u
net = net/k
print("\n \n \n")
print("For Sequence1, Rapid Alignment,")
print("Total Base Pairs",tt)
print("Total Miss", m)
print("Net Accuracy",net)
# Out:
# Iteration 0 Accuracy 0.74929
# Iteration 1 Accuracy 0.71425
# Iteration 2 Accuracy 0.74045
# Iteration 3 Accuracy 0.78975
# Iteration 4 Accuracy 0.65176
# Iteration 5 Accuracy 0.79728
# Iteration 6 Accuracy 0.67259
# Iteration 7 Accuracy 0.82102
# Iteration 8 Accuracy 0.74052
# Iteration 9 Accuracy 0.74889
# Iteration 10 Accuracy 0.7916
# Iteration 11 Accuracy 0.74645
# Iteration 12 Accuracy 0.68002
# Iteration 13 Accuracy 0.70518
# Iteration 14 Accuracy 0.79763
# Iteration 15 Accuracy 0.758
# Iteration 16 Accuracy 0.7897
# Iteration 17 Accuracy 0.80494
# Iteration 18 Accuracy 0.74381
# Iteration 19 Accuracy 0.80818
# Iteration 20 Accuracy 0.74399
# Iteration 21 Accuracy 0.82684
# Iteration 22 Accuracy 0.71585
# Iteration 23 Accuracy 0.68377
# Iteration 24 Accuracy 0.81762
# Iteration 25 Accuracy 0.69506
# Iteration 26 Accuracy 0.81675
# Iteration 27 Accuracy 0.7119
# Iteration 28 Accuracy 0.82472
# Iteration 29 Accuracy 0.80807
# Iteration 30 Accuracy 0.75303
# ...

# %%
def read_only_lines(filepath, start, finish):
    f = open(filepath)
    for ii,line in enumerate(f):
        if ii>=start and ii<finish:
            yield line
        elif ii>=finish:
            return

def check_similairty(str1,str2):
    miss=0
    for i in range(len(str1)):
        if str1!=str2:
            miss+=1
    return round(( 1 - miss/len(str1))*100,4), len(str1), miss

file_path1 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq2rapid.txt'
file_path2 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq2sw.txt'
k = len(enumerate(f))
net = 0
tt = 0
m = 0
for i in range(k):
    str1 = read_only_lines(file_path1,k,k+10)
    str2 = read_only_lines(file_path2,k,k+10)
    acc,tt,m = check_similarity(str1,str2)
    print("Iteration ",i, "Accuracy ",u)
    net+=u
net = net/k
print("\n \n \n")
print("For Sequence2, Rapid Alignment,")
print("Total Base Pairs",tt)
print("Total Miss", m)
print("Net Accuracy",net)
# Out:
# Iteration 0 Accuracy 0.81403
# Iteration 1 Accuracy 0.65428
# Iteration 2 Accuracy 0.77492
# Iteration 3 Accuracy 0.79783
# Iteration 4 Accuracy 0.7882
# Iteration 5 Accuracy 0.69275
# Iteration 6 Accuracy 0.77519
# Iteration 7 Accuracy 0.72772
# Iteration 8 Accuracy 0.74093
# Iteration 9 Accuracy 0.74335
# Iteration 10 Accuracy 0.67052
# Iteration 11 Accuracy 0.65175
# Iteration 12 Accuracy 0.77276
# Iteration 13 Accuracy 0.78226
# Iteration 14 Accuracy 0.7641
# Iteration 15 Accuracy 0.72372
# Iteration 16 Accuracy 0.77381
# Iteration 17 Accuracy 0.68616
# Iteration 18 Accuracy 0.74435
# Iteration 19 Accuracy 0.76256
# Iteration 20 Accuracy 0.66437
# Iteration 21 Accuracy 0.82443
# Iteration 22 Accuracy 0.69816
# Iteration 23 Accuracy 0.76012
# Iteration 24 Accuracy 0.707
# Iteration 25 Accuracy 0.6528
# Iteration 26 Accuracy 0.66404
# Iteration 27 Accuracy 0.6505
# Iteration 28 Accuracy 0.70927
# Iteration 29 Accuracy 0.70049
# Iteration 30 Accuracy 0.79298
# ...

# %% [markdown]
# ### Linear Banded Gap Penalty

# %%
def read_only_lines(filepath, start, finish):
    f = open(filepath)
    for ii,line in enumerate(f):
        if ii>=start and ii<finish:
            yield line
        elif ii>=finish:
            return

def check_similairty(str1,str2):
    miss=0
    for i in range(len(str1)):
        if str1!=str2:
            miss+=1
    return round(( 1 - miss/len(str1))*100,4), len(str1), miss

file_path1 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq1rapid_lin.txt'
file_path2 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq1sw.txt'
k = len(enumerate(f))
net = 0
tt = 0
m = 0
for i in range(k):
    str1 = read_only_lines(file_path1,k,k+10)
    str2 = read_only_lines(file_path2,k,k+10)
    acc,tt,m = check_similarity(str1,str2)
    print("Iteration ",i, "Accuracy ",u)
    net+=u
net = net/k
print("\n \n \n")
print("For Sequence1, Linear Banded Gap Alignment,")
print("Total Base Pairs",tt)
print("Total Miss", m)
print("Net Accuracy",net)
# Out:
# Iteration 0 Accuracy 0.6784
# Iteration 1 Accuracy 0.75215
# Iteration 2 Accuracy 0.67246
# Iteration 3 Accuracy 0.77128
# Iteration 4 Accuracy 0.75459
# Iteration 5 Accuracy 0.71171
# Iteration 6 Accuracy 0.65447
# Iteration 7 Accuracy 0.6683
# Iteration 8 Accuracy 0.65775
# Iteration 9 Accuracy 0.76641
# Iteration 10 Accuracy 0.75906
# Iteration 11 Accuracy 0.73349
# Iteration 12 Accuracy 0.75142
# Iteration 13 Accuracy 0.79184
# Iteration 14 Accuracy 0.66576
# Iteration 15 Accuracy 0.63307
# Iteration 16 Accuracy 0.72279
# Iteration 17 Accuracy 0.7779
# Iteration 18 Accuracy 0.72425
# Iteration 19 Accuracy 0.79884
# Iteration 20 Accuracy 0.63379
# Iteration 21 Accuracy 0.65337
# Iteration 22 Accuracy 0.72753
# Iteration 23 Accuracy 0.66837
# Iteration 24 Accuracy 0.73686
# Iteration 25 Accuracy 0.6596
# Iteration 26 Accuracy 0.78143
# Iteration 27 Accuracy 0.6706
# Iteration 28 Accuracy 0.71065
# Iteration 29 Accuracy 0.65842
# Iteration 30 Accuracy 0.75656
# ...

# %%
def read_only_lines(filepath, start, finish):
    f = open(filepath)
    for ii,line in enumerate(f):
        if ii>=start and ii<finish:
            yield line
        elif ii>=finish:
            return

def check_similairty(str1,str2):
    miss=0
    for i in range(len(str1)):
        if str1!=str2:
            miss+=1
    return round(( 1 - miss/len(str1))*100,4), len(str1), miss

file_path1 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq2rapid_lin.txt'
file_path2 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq2sw.txt'
k = len(enumerate(f))
net = 0
tt = 0
m = 0
for i in range(k):
    str1 = read_only_lines(file_path1,k,k+10)
    str2 = read_only_lines(file_path2,k,k+10)
    acc,tt,m = check_similarity(str1,str2)
    print("Iteration ",i, "Accuracy ",u)
    net+=u
net = net/k
print("\n \n \n")
print("For Sequence2, Linear Banded Gap Alignment,")
print("Total Base Pairs",tt)
print("Total Miss", m)
print("Net Accuracy",net)
# Out:
# Iteration 0 Accuracy 0.74322
# Iteration 1 Accuracy 0.67015
# Iteration 2 Accuracy 0.75585
# Iteration 3 Accuracy 0.71556
# Iteration 4 Accuracy 0.76539
# Iteration 5 Accuracy 0.68329
# Iteration 6 Accuracy 0.78598
# Iteration 7 Accuracy 0.64579
# Iteration 8 Accuracy 0.65027
# Iteration 9 Accuracy 0.6324
# Iteration 10 Accuracy 0.78835
# Iteration 11 Accuracy 0.76028
# Iteration 12 Accuracy 0.65234
# Iteration 13 Accuracy 0.75816
# Iteration 14 Accuracy 0.77384
# Iteration 15 Accuracy 0.77248
# Iteration 16 Accuracy 0.70626
# Iteration 17 Accuracy 0.7121
# Iteration 18 Accuracy 0.75354
# Iteration 19 Accuracy 0.7821
# Iteration 20 Accuracy 0.76855
# Iteration 21 Accuracy 0.66597
# Iteration 22 Accuracy 0.79653
# Iteration 23 Accuracy 0.79561
# Iteration 24 Accuracy 0.77337
# Iteration 25 Accuracy 0.64931
# Iteration 26 Accuracy 0.70737
# Iteration 27 Accuracy 0.69931
# Iteration 28 Accuracy 0.6634
# Iteration 29 Accuracy 0.63952
# Iteration 30 Accuracy 0.70533
# ...

# %% [markdown]
# ### Affine Gap Penalty

# %%
def read_only_lines(filepath, start, finish):
    f = open(filepath)
    for ii,line in enumerate(f):
        if ii>=start and ii<finish:
            yield line
        elif ii>=finish:
            return

def check_similairty(str1,str2):
    miss=0
    for i in range(len(str1)):
        if str1!=str2:
            miss+=1
    return round(( 1 - miss/len(str1))*100,4), len(str1), miss

file_path1 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq1rapid_aff.txt'
file_path2 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq1sw.txt'
k = len(enumerate(f))
net = 0
tt = 0
m = 0
for i in range(k):
    str1 = read_only_lines(file_path1,k,k+10)
    str2 = read_only_lines(file_path2,k,k+10)
    acc,tt,m = check_similarity(str1,str2)
    print("Iteration ",i, "Accuracy ",u)
    net+=u
net = net/k
print("\n \n \n")
print("For Sequence1, Affine Gap Alignment,")
print("Total Base Pairs",tt)
print("Total Miss", m)
print("Net Accuracy",net)
# Out:
# Iteration 0 Accuracy 0.81507
# Iteration 1 Accuracy 0.76205
# Iteration 2 Accuracy 0.69978
# Iteration 3 Accuracy 0.7545
# Iteration 4 Accuracy 0.74956
# Iteration 5 Accuracy 0.69573
# Iteration 6 Accuracy 0.75985
# Iteration 7 Accuracy 0.67723
# Iteration 8 Accuracy 0.76641
# Iteration 9 Accuracy 0.80534
# Iteration 10 Accuracy 0.74006
# Iteration 11 Accuracy 0.91557
# Iteration 12 Accuracy 0.70505
# Iteration 13 Accuracy 0.72749
# Iteration 14 Accuracy 0.73807
# Iteration 15 Accuracy 0.71758
# Iteration 16 Accuracy 0.88839
# Iteration 17 Accuracy 0.91495
# Iteration 18 Accuracy 0.69212
# Iteration 19 Accuracy 0.85687
# Iteration 20 Accuracy 0.78847
# Iteration 21 Accuracy 0.79912
# Iteration 22 Accuracy 0.78777
# Iteration 23 Accuracy 0.88825
# Iteration 24 Accuracy 0.67113
# Iteration 25 Accuracy 0.8538
# Iteration 26 Accuracy 0.77349
# Iteration 27 Accuracy 0.82625
# Iteration 28 Accuracy 0.72584
# Iteration 29 Accuracy 0.83421
# Iteration 30 Accuracy 0.86506
# ...

# %%
def read_only_lines(filepath, start, finish):
    f = open(filepath)
    for ii,line in enumerate(f):
        if ii>=start and ii<finish:
            yield line
        elif ii>=finish:
            return

def check_similairty(str1,str2):
    miss=0
    for i in range(len(str1)):
        if str1!=str2:
            miss+=1
    return round(( 1 - miss/len(str1))*100,4), len(str1), miss

file_path1 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq2rapid_aff.txt'
file_path2 = 'C:\Users\yashn\Desktop\PIM\Fin\output\seq2sw.txt'
k = len(enumerate(f))
net = 0
tt = 0
m = 0
for i in range(k):
    str1 = read_only_lines(file_path1,k,k+10)
    str2 = read_only_lines(file_path2,k,k+10)
    acc,tt,m = check_similarity(str1,str2)
    print("Iteration ",i, "Accuracy ",u)
    net+=u
net = net/k
print("\n \n \n")
print("For Sequence2, Affine Gap Alignment,")
print("Total Base Pairs",tt)
print("Total Miss", m)
print("Net Accuracy",net)
# Out:
# Iteration 0 Accuracy 0.78151
# Iteration 1 Accuracy 0.89384
# Iteration 2 Accuracy 0.77287
# Iteration 3 Accuracy 0.80871
# Iteration 4 Accuracy 0.804
# Iteration 5 Accuracy 0.79685
# Iteration 6 Accuracy 0.83709
# Iteration 7 Accuracy 0.73361
# Iteration 8 Accuracy 0.86056
# Iteration 9 Accuracy 0.79529
# Iteration 10 Accuracy 0.82026
# Iteration 11 Accuracy 0.70559
# Iteration 12 Accuracy 0.87784
# Iteration 13 Accuracy 0.72109
# Iteration 14 Accuracy 0.74529
# Iteration 15 Accuracy 0.80904
# Iteration 16 Accuracy 0.78162
# Iteration 17 Accuracy 0.84735
# Iteration 18 Accuracy 0.8471
# Iteration 19 Accuracy 0.79928
# Iteration 20 Accuracy 0.86407
# Iteration 21 Accuracy 0.72094
# Iteration 22 Accuracy 0.73064
# Iteration 23 Accuracy 0.72753
# Iteration 24 Accuracy 0.87057
# Iteration 25 Accuracy 0.82427
# Iteration 26 Accuracy 0.8118
# Iteration 27 Accuracy 0.80876
# Iteration 28 Accuracy 0.72099
# Iteration 29 Accuracy 0.70462
# Iteration 30 Accuracy 0.73283
# ...

# %% [markdown]
# ## Timing & Memory Analysis

# %%
rapid = pd.read_csv(r'C:\Users\yashn\Desktop\PIM\Fin\output\seq1rapid.csv')
lin = pd.read_csv(r'C:\Users\yashn\Desktop\PIM\Fin\output\seq1rapid_lin.csv')
aff = pd.read_csv(r'C:\Users\yashn\Desktop\PIM\Fin\output\seq1rapid_aff.csv')

# %%
rapid
# Out:
#       Unnamed: 0  Iteration      Time  Memory
# 0              0          0  7216.865  10.950
# 1              1          1  6669.556  11.458
# 2              2          2  7851.067  11.977
# 3              3          3  6892.053   9.481
# 4              4          4  7587.319   9.552
# ...          ...        ...       ...     ...
# 1003        1003       1003  6314.892   8.748
# 1004        1004       1004  6025.581  10.990
# 1005        1005       1005  7649.087  10.981
# 1006        1006       1006  7114.754   9.313
# 1007        1007       1007  7026.634  10.869
#
# [1008 rows x 4 columns]

# %%
lin
# Out:
#       Unnamed: 0  Iteration     Time  Memory
# 0              0          0  535.024   5.849
# 1              1          1  598.888   5.777
# 2              2          2  496.601   5.873
# 3              3          3  424.796   6.265
# 4              4          4  528.479   6.301
# ...          ...        ...      ...     ...
# 1003        1003       1003  525.035   5.708
# 1004        1004       1004  558.312   6.210
# 1005        1005       1005  413.463   6.332
# 1006        1006       1006  584.084   6.865
# 1007        1007       1007  534.735   5.924
#
# [1008 rows x 4 columns]

# %%
aff
# Out:
#       Unnamed: 0  Iteration     Time  Memory
# 0              0          0  531.006   7.239
# 1              1          1  520.826   7.109
# 2              2          2  633.032   7.685
# 3              3          3  511.527   8.690
# 4              4          4  645.091   7.838
# ...          ...        ...      ...     ...
# 1003        1003       1003  602.115   7.594
# 1004        1004       1004  561.960   8.568
# 1005        1005       1005  633.269   8.845
# 1006        1006       1006  526.897   8.019
# 1007        1007       1007  510.453   8.735
#
# [1008 rows x 4 columns]

# %%
print("For Sequence 2,")
print("Average Time for Rapid", round(rapid['Time'].mean()/1000,3), "sec")
print("Average Time for Linear Bandgap Banded Penalty", round(lin['Time'].mean()/1000,3),"sec")
print("Average Time for Affine Bandgap Banded Penalty", round(aff['Time'].mean()/1000,3), "sec")

plt.plot(aff['Iteration'],aff['Time'],label = 'Affine Band', color='b', linestyle='dotted')
plt.plot(lin['Iteration'],lin['Time'],label = 'Linear Band', color='g', linestyle='-')
plt.plot(rapid['Iteration'],rapid['Time'],label = 'Rapid Band', color='r', linestyle='--')
plt.xlabel('Iteration')
plt.ylabel('Time(ms)')
plt.legend()
plt.title('Time Analysis')
plt.show()
# Out:
# For Sequence 2,
# Average Time for Rapid 7.029 sec
# Average Time for Linear Bandgap Banded Penalty 0.5 sec
# Average Time for Affine Bandgap Banded Penalty 0.575 sec

# %%
print("For Sequence 2,")
print("Average Memory for Rapid", round(rapid['Memory'].mean(),3), "MB")
print("Average Memory for Linear Bandgap Banded Penalty", round(lin['Memory'].mean(),3),"MB")
print("Average Memory for Affine Bandgap Banded Penalty", round(aff['Memory'].mean(),3), "MB")

plt.plot(aff['Iteration'],aff['Memory'],label = 'Affine Band', color='b', linestyle='dotted')
plt.plot(lin['Iteration'],lin['Memory'],label = 'Linear Band', color='g', linestyle='-')
plt.plot(rapid['Iteration'],rapid['Memory'],label = 'Rapid Band', color='r', linestyle='--')
plt.xlabel('Iteration')
plt.ylabel('Memory(MB)')
plt.legend()
plt.title('Memory Analysis')
plt.show()
# Out:
# For Sequence 2,
# Average Memory for Rapid 10.311 MB
# Average Memory for Linear Bandgap Banded Penalty 6.303 MB
# Average Memory for Affine Bandgap Banded Penalty 7.903 MB

# %%
print("For Sequence 1,")
print("Average Time for Rapid", round(rapid['Time'].mean()/1000,3), "sec")
print("Average Time for Linear Bandgap Banded Penalty", round(lin['Time'].mean()/1000,3),"sec")
print("Average Time for Affine Bandgap Banded Penalty", round(aff['Time'].mean()/1000,3), "sec")

plt.plot(aff['Iteration'],aff['Time'],label = 'Affine Band', color='b', linestyle='dotted')
plt.plot(lin['Iteration'],lin['Time'],label = 'Linear Band', color='g', linestyle='-')
plt.plot(rapid['Iteration'],rapid['Time'],label = 'Rapid Band', color='r', linestyle='--')
plt.xlabel('Iteration')
plt.ylabel('Time(ms)')
plt.legend()
plt.title('Time Analysis')
plt.show()
# Out:
# For Sequence 1,
# Average Time for Rapid 7.015 sec
# Average Time for Linear Bandgap Banded Penalty 0.501 sec
# Average Time for Affine Bandgap Banded Penalty 0.576 sec

# %%
print("For Sequence 1,")
print("Average Memory for Rapid", round(rapid['Memory'].mean(),3), "MB")
print("Average Memory for Linear Bandgap Banded Penalty", round(lin['Memory'].mean(),3),"MB")
print("Average Memory for Affine Bandgap Banded Penalty", round(aff['Memory'].mean(),3), "MB")

plt.plot(aff['Iteration'],aff['Memory'],label = 'Affine Band', color='b', linestyle='dotted')
plt.plot(lin['Iteration'],lin['Memory'],label = 'Linear Band', color='g', linestyle='-')
plt.plot(rapid['Iteration'],rapid['Memory'],label = 'Rapid Band', color='r', linestyle='--')
plt.xlabel('Iteration')
plt.ylabel('Memory(MB)')
plt.legend()
plt.title('Memory Analysis')
plt.show()
# Out:
# For Sequence 1,
# Average Memory for Rapid 10.312 MB
# Average Memory for Linear Bandgap Banded Penalty 6.312 MB
# Average Memory for Affine Bandgap Banded Penalty 7.921 MB
